# %% [markdown]
# - Vẽ đồ thị hàm x = y**2 và x = y trên cùng 1 trục toạ độ.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(10)

# %%
plt.plot(x, x), plt.plot(x, x**2)
# Out:
# ([<matplotlib.lines.Line2D at 0x7f445f1beac8>],
#  [<matplotlib.lines.Line2D at 0x7f445f1becc0>])
